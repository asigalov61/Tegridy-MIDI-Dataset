# %% [markdown]
# <a href="https://colab.research.google.com/github/asigalov61/Tegridy-MIDI-Dataset/blob/master/Advanced_MIDI_Channel_Splitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced MIDI Channel Splitter (ver 1.0)
#
# ***
#
# ## Full-featured advanced MIDI Channel Splitter
#
# ***
#
# ### Project Los Angeles
#
# ### Tegridy Code 2020
#
#
# ***

# %%
#@title Install Dependencies

# !curl -L "https://raw.githubusercontent.com/asigalov61/Meddleying-MAESTRO/main/MIDI.py" > 'MIDI.py'

# %%
#@title Import Modules and Create IO dirs

import MIDI


import glob
import os
import tqdm.auto
from google.colab import drive

#@title Choose names for Source and Destination folders for conversion
source_dir = "/content/S" #@param {type:"string"}
dest_dir = "/content/D" #@param {type:"string"}
source_path = source_dir
dest_path = dest_dir
if not os.path.exists(source_path):
    os.makedirs(source_path)
if not os.path.exists(dest_path):
    os.makedirs(dest_path)

# %%
#@title (Optional) Download and Unzip Tegridy Special MIDI Dataset (Piano/Violin only)
# %cd /content/S
# !wget 'https://github.com/asigalov61/Tegridy-MIDI-Dataset/raw/master/Tegridy-MIDI-Dataset-CC-BY-NC-SA.zip'
# !unzip -j 'Tegridy-MIDI-Dataset-CC-BY-NC-SA.zip'
# !rm 'Tegridy-MIDI-Dataset-CC-BY-NC-SA.zip'
# %cd /content/

# %%
#@title A simple code to unzip MIDI datasets without any hastle
# !mkdir /content/D/
# %cd /content/S/
# !unzip -j /content/S/*.zip
# !rm /content/S/*.zip
# %cd /content/

# %%
#@title Split Channels.
input_files_extension = "*.mid" #@param ["*.mid", "*.midi", "*.kar", "*.*"]
output_extension = ".mid" #@param {type:"string"}
output_files_names_tag = "_split_.mid" #@param {type:"string"}

split_channel0 = True #@param {type:"boolean"}
split_channel1 = True #@param {type:"boolean"}
split_channel2 = True #@param {type:"boolean"}
split_channel3 = True #@param {type:"boolean"}
split_channel4 = True #@param {type:"boolean"}
split_channel5 = True #@param {type:"boolean"}
split_channel6 = True #@param {type:"boolean"}
split_channel7 = True #@param {type:"boolean"}
split_channel8 = True #@param {type:"boolean"}
split_channel9 = True #@param {type:"boolean"}
split_channel10 = True #@param {type:"boolean"}
split_channel11 = True #@param {type:"boolean"}
split_channel12 = True #@param {type:"boolean"}
split_channel13 = True #@param {type:"boolean"}
split_channel14 = True #@param {type:"boolean"}
split_channel15 = True #@param {type:"boolean"}
channel0 = []
channel1 = []
channel2 = []
channel3 = []
channel4 = []
channel5 = []
channel6 = []
channel7 = []
channel8 = []
channel9 = []
channel10 = []
channel11 = []
channel12 = []
channel13 = []
channel14 = []
channel15 = []
channel0_events_counter = 0
channel1_events_counter = 0
channel2_events_counter = 0
channel3_events_counter = 0
channel4_events_counter = 0
channel5_events_counter = 0
channel6_events_counter = 0
channel7_events_counter = 0
channel8_events_counter = 0
channel9_events_counter = 0
channel10_events_counter = 0
channel11_events_counter = 0
channel12_events_counter = 0
channel13_events_counter = 0
channel14_events_counter = 0
channel15_events_counter = 0
opus_in_events_count = 0
opus = []
opus_in = []
opus_out = []
sf = 0
split_files_counter = 0
channels_events_counter = 0
midi_file = ''
midi_file_out = ''
outname = ''
debug = False #@param {type:"boolean"}

if not os.path.exists(dest_path):
    os.makedirs(dest_path)

# Create a list of paths and files. Select desired MIDI extension
source_files = os.listdir(source_path)
if debug: print(source_files)

# Define reducer/parser function and input desired instrument to reduce to { run: "auto", display-mode: "form" }

def MIDI_Splitter(fname):



    return split_files_counter,
    opus_in_events_count,
    channel0_events_counter,
    channel1_events_counter,
    channel2_events_counter,
    channel3_events_counter,
    channel4_events_counter,
    channel5_events_counter,
    channel6_events_counter,
    channel7_events_counter,
    channel8_events_counter,
    channel9_events_counter,
    channel10_events_counter,
    channel11_events_counter,
    channel12_events_counter,
    channel13_events_counter,
    channel14_events_counter,
    channel15_events_counter
                         
print('Splitting...')

for fname in tqdm.auto.tqdm(source_files):
  #try:
  fname = os.path.join(source_path, fname)
  midi_file = open(fname, 'rb')
  opus_in = MIDI.midi2opus(midi_file.read())
  opus_in_events_count += len(opus_in[1])
  midi_file.close()

  channel0 = MIDI.grep(opus_in, [0])
  channel1 = MIDI.grep(opus_in, [1])
  channel2 = MIDI.grep(opus_in, [2])
  channel3 = MIDI.grep(opus_in, [3])
  channel4 = MIDI.grep(opus_in, [4])
  channel5 = MIDI.grep(opus_in, [5])
  channel6 = MIDI.grep(opus_in, [6])
  channel7 = MIDI.grep(opus_in, [7])
  channel8 = MIDI.grep(opus_in, [8])
  channel9 = MIDI.grep(opus_in, [9])
  channel10 = MIDI.grep(opus_in, [10])
  channel11 = MIDI.grep(opus_in, [11])
  channel12 = MIDI.grep(opus_in, [12])
  channel13 = MIDI.grep(opus_in, [13])
  channel14 = MIDI.grep(opus_in, [14])
  channel15 = MIDI.grep(opus_in, [15])

  if split_channel0:
    opus_out = channel0
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_0.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel0_events_counter += len(opus_out[1])

  if split_channel1:
    opus_out = channel1
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_1.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel1_events_counter += len(opus_out[1])

  if split_channel2:
    opus_out = channel2
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_2.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel2_events_counter += len(opus_out[1])

  if split_channel3:      
    opus_out = channel3
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_3.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel3_events_counter += len(opus_out[1])

  if split_channel4:      
    opus_out = channel4
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_4.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel4_events_counter += len(opus_out[1])

  if split_channel5:  
    opus_out = channel5
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_5.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel5_events_counter += len(opus_out[1])
    
  if split_channel6:
    opus_out = channel6
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_6.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel6_events_counter += len(opus_out[1])
    
  if split_channel7:
    opus_out = channel7
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_7.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel7_events_counter += len(opus_out[1])

  if split_channel8:
    opus_out = channel8
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_8.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel8_events_counter += len(opus_out[1])

  if split_channel9:
    opus_out = channel9
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_9.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel9_events_counter += len(opus_out[1])

  if split_channel10:
    opus_out = channel10
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_10.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel10_events_counter += len(opus_out[1])

  if split_channel11:  
    opus_out = channel11
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_11.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel11_events_counter += len(opus_out[1])

  if split_channel12:  
    opus_out = channel12
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_12.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel12_events_counter += len(opus_out[1])

  if split_channel13:  
    opus_out = channel13
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_13.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel13_events_counter += len(opus_out[1])

  if split_channel14:  
    opus_out = channel14
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_14.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel14_events_counter += len(opus_out[1])
                    
  if split_channel15:  
    opus_out = channel15
    outname = fname.replace(output_extension, output_files_names_tag).replace(output_extension, 'MIDI_Channel_15.mid').replace(source_path, dest_path)
    out_file = MIDI.opus2midi(opus_out)
    with open(outname, 'wb') as midi_file_out:
        midi_file_out.write(out_file)
    midi_file_out.close()
    split_files_counter += 1
    channel15_events_counter += len(opus_out[1])

  sf += 1
  #except KeyboardInterrupt:
  #  break
#  except:
#    print('Critical error. Most likely a bad MIDI file. Stopping.')
#    break

channels_events_counter = (channel0_events_counter + 
                           channel1_events_counter + 
                           channel2_events_counter +
                           channel3_events_counter + 
                           channel4_events_counter + 
                           channel5_events_counter +
                           channel6_events_counter +
                           channel7_events_counter + 
                           channel8_events_counter +
                           channel9_events_counter + 
                           channel10_events_counter + 
                           channel11_events_counter +
                           channel12_events_counter +
                           channel13_events_counter + 
                           channel14_events_counter +
                           channel15_events_counter)   



print('Split', len(source_files), 'MIDI files into', sf, 'single MIDI Channel files.')
print('Validated total of', len(os.listdir(dest_path)), 'MIDIs')
print('Total of', opus_in_events_count, 'MIDI events were read from MIDIs.')
print('The disrepancy between the original files and the output files =', abs(opus_in_events_count - channels_events_counter))
print('Total MIDI events for Channel 0:', channel0_events_counter)
print('Total MIDI events for Channel 1:', channel1_events_counter)
print('Total MIDI events for Channel 2:', channel2_events_counter)
print('Total MIDI events for Channel 3:', channel3_events_counter)
print('Total MIDI events for Channel 4:', channel4_events_counter)
print('Total MIDI events for Channel 5:', channel5_events_counter)
print('Total MIDI events for Channel 6:', channel6_events_counter)
print('Total MIDI events for Channel 7:', channel7_events_counter)
print('Total MIDI events for Channel 8:', channel8_events_counter)
print('Total MIDI events for Channel 9:', channel9_events_counter)
print('Total MIDI events for Channel 10:', channel10_events_counter)
print('Total MIDI events for Channel 11:', channel11_events_counter)
print('Total MIDI events for Channel 12:', channel12_events_counter)
print('Total MIDI events for Channel 13:', channel13_events_counter)
print('Total MIDI events for Channel 14:', channel14_events_counter)
print('Total MIDI events for Channel 15:', channel15_events_counter)
print('This is approximatelly', int(opus_in_events_count / 16), 'MIDI events per split output MIDI file.')
print('Enjoy!')

# %%
#@title Zip Output
# %cd /content/
# !zip -r /content/Advanced-MIDI-Channel-Splitter-Output.zip /content/D/

# %%
#@title Mount Google Drive (Standard GD Connect Code)
drive.mount('/content/drive')

# %%
#@title Dismount Google Drive if you need to zip the root
from google.colab import drive
drive.flush_and_unmount()
